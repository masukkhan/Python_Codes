# %%
name = "masuk"
id= 26
cgpa = 3.6

print("my name is " +name)
print("my id is " ,id,)
print("my cgpa is",cgpa,)
print("sharuk is " "Bukachoda")


#numerical 
a= 8
b= 4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# my name is masuk
# my id is  26
# my cgpa is 3.6
# sharuk is Bukachoda
# 12
# 4
# 32
# 2.0
# 0
# 2
# 4096
