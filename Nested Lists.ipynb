# %%
if __name__ == '__main__':
    students ={}
    for _ in range(int(input())):
        name = input()
        score = float(input())
        students[name] = score
mx = max(students.values())
student = sorted(students.items())
# print(student)
# mx2 = -9
# for i in students.values():
#     if i < mx and i >mx2:
#         mx2 = i
# print(mx2)
print(list(students.keys())[1])
# Out:
# 2
# masuk
# 4
# asib
# 5
# asib
