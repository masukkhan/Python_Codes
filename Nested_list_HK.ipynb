# %%
l=[]
l1=[]
for _ in range(int(input())):
    name = input()
    score = float(input())
    l.append([name,score])
    l1.append(score)
l1 = sorted(set(l1))
name=[]
# print(l)
for i in range(0,len(l)):
    if l[i][1] == l1[1]:
         name.append(l[i][0])
name = sorted(name)
for i in name:
    # print(i)
print()
# Out:
# 3
# Harry
# 37.21
# Berry
# 37.21
# Tina
# 37.2
# [['Harry', 37.21], ['Berry', 37.21], ['Tina', 37.2]]
# Berry
# Harry
