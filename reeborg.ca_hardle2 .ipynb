# %%
def turn_right():
    turn_left()
    turn_left()
    turn_left()
    
def move_forward():
    move()
def turn_right2():
    turn_left()
    turn_left()
    
def first_move():
    move_forward()
    turn_left()
    move_forward()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()
#for i in range(0,6):
    #first_move()
while not at_goal():
    first_move()
