# %%
from replit import clear
import math
#HINT: You can call clear() to clear the output in the console.
from art import logo
print(logo)

print("Welcome to the auction program")

bidders ={}
play = []
highest_bid = 0
high_bidder = ""

while True:
  name_key =input("whats your name ")
  bid_amount =input("whats your bid? ")
  bidders[name_key] = bid_amount

  for i in (bidders):
    value = int(bidders[i])
    if highest_bid < value:
      highest_bid = value
      high_bidder = i

  play = input("you want to play again: yes / no ")
  if play == "yes":
    continue
  else:
    print(f"Highest bidder is :{high_bidder} = {highest_bid}")
    break
